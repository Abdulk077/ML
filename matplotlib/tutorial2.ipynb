# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
comapny=['GOOGL','AMZN', 'MSFT', 'FB']
revenue=[90,136,89,27]
profit=[40,2,34,12]

# %%
xpos = np.arange(len(comapny))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(xpos,comapny)
plt.ylabel("revenue(bln)")
plt.title("Us tect stocks")
plt.bar(xpos-0.5,revenue , width=0.3, label="revennue")
plt.bar(xpos,profit , width=0.3,label="profit")
plt.legend()
