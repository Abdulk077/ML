# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6]
y=[50,60,70,30,45,20]

# %%
plt.plot(x,y)

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,34,28,35,61]
min_t = [43,42,44,41,33,35,37]
avg_t = [45,48,48,46,40,42,41]

# %%
plt.xlabel("days")
plt.ylabel("Temp")
plt.title("weather")
plt.plot(days,max_t, label="max")
plt.plot(days,min_t , label="min")
plt.plot(days,avg_t , label="avg")

plt.legend( )
